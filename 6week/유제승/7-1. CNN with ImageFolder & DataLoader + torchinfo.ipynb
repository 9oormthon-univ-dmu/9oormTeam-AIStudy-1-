# %% [markdown]
# <br><br>
#
# <p style="color:red; font-size:1.3em;">종종 Jupyter notebook에서 <b>Kernel Dead</b> 메시지가 뜨면서 강제로 kernel이 종료될 수 있습니다.</p><br>
# <p style="font-size:1.3em;">이 현상은 이미지 파일 등을 처리할 때 컴퓨터의 메모리 부족 등의 이유로 발생할 수 있으며,<br><br>
# 만일 Kernel Dead 메시지가 뜨면 <span style="color:red;"> <b>다시 첫번째 Cell부터 실행하며 내려가다가 해당 Cell을 제외하고 실행</b>시켜주세요!</span></p>
#
# <br><br>

# %% [markdown]
# <hr>
# <br>
#
# #### **Vision** - **torchvision**.datasets @ https://pytorch.org/vision/stable/datasets.html <br><br> :	CIFAR10 / FashionMNIST / Food101 / ImageNet / MS Coco Detection / etc.
# <br>
#
# <hr>
# <br>
#
# #### **Text** - **torchtext**.datasets @ https://pytorch.org/text/stable/datasets.html <br><br> :	IMDB / Amazon Reviews / Yelp Reviews / SQuAD / etc.
# <br>
#
# <hr>
# <br>
#
# #### **Audio** - **torchaudio**.datasets @ https://pytorch.org/audio/stable/datasets.html
# <br>
#
# <hr>
# <br>
#
# #### **Recommendation-system** - **torchrec**.datasets @ https://pytorch.org/torchrec/torchrec.datasets.html
# <br>
#
# <hr>
# <br>
#
# #### **Data Pipelines** - **TorchData**(Beta) @ https://pytorch.org/data/beta/index.html
# <br>
#
# <hr>
# <br>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from tqdm.auto import tqdm

import torch
from torch import nn

from torch.utils.data import DataLoader # class for loading the dataset (Dataset -> Batches)
from torchmetrics import Accuracy

import torchvision
from torchvision import transforms
from torchvision.datasets import ImageFolder # Load "Image" data from selected "Folder"s

print(torch.__version__)
print(torchvision.__version__)
# Out:
# 2.1.0
# 0.16.0

# %% [markdown]
# <br>
# <br>
#
# # 1. Prepare the dataset
# <br>
#
# ### * Original Dataset : **Food-101** @ https://data.vision.ee.ethz.ch/cvl/datasets_extra/food-101/
#
# <br>
#
# - **101** food categories<br>
# - **101,000** images<br>
# - **750** training images & **250** test images per class<br>
# - rescaled to have a **maximum side length of 512 pixels**

# %%
import zipfile
import os
import glob
import random

# %%
with zipfile.ZipFile("data_food101/Food101.zip", "r") as zip_f:
    
    print("Unzipping the dataset.") 
    
    zip_f.extractall("data_food101/data") # "extract" "all" files
# Out:
# Unzipping the dataset.

# %%
for data in os.walk("data_food101/data"): # 지정된 디렉토리 내부를 거닐며("walk") 조회
    print(data, '\n') 
    
    # dir_path, dir_names, file_names
# Out:
# ('data_food101/data', ['test', 'train'], ['.DS_Store'])
#
# ('data_food101/data/test', ['steak', 'sushi', 'pizza'], [])
#
# ('data_food101/data/test/steak', [], ['296375.jpg', '673127.jpg', '894825.jpg', '1868005.jpg', '27415.jpg', '1016217.jpg', '1285886.jpg', '502076.jpg', '3424937.jpg', '690177.jpg', '354513.jpg', '2117351.jpg', '100274.jpg', '2144308.jpg', '966174.jpg', '1882831.jpg', '3873283.jpg', '1302563.jpg', '1627703.jpg'])
#
# ('data_food101/data/test/sushi', [], ['858157.jpg', '988559.jpg', '479711.jpg', '1987407.jpg', '1230335.jpg', '1245193.jpg', '2741434.jpg', '1434806.jpg', '3837522.jpg', '207578.jpg', '3177743.jpg', '2385731.jpg', '1680893.jpg', '175783.jpg', '1172255.jpg', '887831.jpg', '2715127.jpg', '2190404.jpg', '684266.jpg', '3806282.jpg', '2540511.jpg', '1742201.jpg', '46797.jpg', '499605.jpg', '1600999.jpg', '2276986.jpg', '719108.jpg', '343036.jpg', '3196729.jpg', '2394442.jpg', '2521706.jpg'])
#
# ('data_food101/data/test/pizza', [], ['195160.jpg', '1687143.jpg', '971934.jpg', '344397.jpg', '416067.jpg', '194643.jpg', '2111981.jpg', '2236338.jpg', '2124579.jpg', '714866.jpg', '2871261.jpg', '2003290.jpg', '1503858.jpg', '540882.jpg', '3092704.jpg', '2019408.jpg', '648055.jpg', '309892.jpg', '398345.jpg', '2218680.jpg', '930553.jpg', '1925494.jpg', '2508636.jpg', '1152100.jpg', '3475871.jpg'])
#
# ('data_food101/data/train', ['steak', 'sushi', 'pizza'], [])
#
# ('data_food101/data/train/steak', [], ['239025.jpg', '1598345.jpg', '3074367.jpg', '2979061.jpg', '914570.jpg', '167069.jpg', '231296.jpg', '2324994.jpg', '2603058.jpg', '1961025.jpg', '1615395.jpg', '2606444.jpg', '355715.jpg', '2163079.jpg', '1736968.jpg', '2878151.jpg', '1976160.jpg', '1382427.jpg', '830007.jpg', '256592.jpg', '2561199.jpg', '3142674.jpg', '1966300.jpg', '1225762.jpg', '2287136.jpg', '75537.jpg', '461689.jpg', '937133.jpg', '2881783.jpg', '443210.jpg', '100135.jpg', '735441.jpg', '3727491.jpg', '214320.jpg', '339891.jpg', '2129685.jpg', '3518960.jpg', '176508.jpg', '1787505.jpg', '3142045.jpg', '2222018.jpg', '3577618.jpg', '2707522.jpg', '2017387.jpg', '2087958.jpg', '2628106.jpg', '2614189.jpg', '2648423.jpg', '2629750.jpg', '165639.jpg', '1257104.jpg', '234626.jpg', '1849463.jpg', '421476.jpg', '2013535.jpg', '3245622.jpg', '1761285.jpg', '2614649.jpg', '2880035.jpg', '1647351.jpg', '97656.jpg', '1937872.jpg', '922752.jpg', '3727036.jpg', '2254705.jpg', '1624747.jpg', '1413972.jpg', '1621763.jpg', '2825100.jpg', '560503.jpg', '225990.jpg', '1839481.jpg', '1264154.jpg', '482022.jpg', '3857508.jpg'])
#
# ('data_food101/data/train/sushi', [], ['3081701.jpg', '17704.jpg', '1552504.jpg', '121940.jpg', '2813454.jpg', '748830.jpg', '3353428.jpg', '2873571.jpg', '840444.jpg', '3579071.jpg', '686426.jpg', '821108.jpg', '424994.jpg', '2574453.jpg', '3360232.jpg', '1551817.jpg', '1221830.jpg', '773725.jpg', '1232045.jpg', '1214108.jpg', '2720223.jpg', '385154.jpg', '765684.jpg', '148799.jpg', '169392.jpg', '14046.jpg', '710379.jpg', '1615453.jpg', '794647.jpg', '1575445.jpg', '2797464.jpg', '497686.jpg', '2641778.jpg', '93139.jpg', '3251688.jpg', '1571146.jpg', '1280119.jpg', '2004525.jpg', '2590819.jpg', '700405.jpg', '170385.jpg', '929471.jpg', '2871052.jpg', '2492146.jpg', '2017378.jpg', '3004029.jpg', '200025.jpg', '1129338.jpg', '2019344.jpg', '1209865.jpg', '2021381.jpg', '1957449.jpg', '377047.jpg', '390178.jpg', '1070104.jpg', '2267190.jpg', '268990.jpg', '2323548.jpg', '542188.jpg', '1138695.jpg', '3426958.jpg', '307738.jpg', '2980779.jpg', '2175561.jpg', '843815.jpg', '2021685.jpg', '2674024.jpg', '3360207.jpg', '855721.jpg', '2120573.jpg', '3107839.jpg', '3737197.jpg'])
#
# ('data_food101/data/train/pizza', [], ['1033251.jpg', '29417.jpg', '928670.jpg', '1968947.jpg', '300869.jpg', '2885796.jpg', '2291093.jpg', '1089334.jpg', '3589437.jpg', '3505182.jpg', '1524655.jpg', '1654444.jpg', '2569760.jpg', '2924941.jpg', '2687575.jpg', '2382016.jpg', '320570.jpg', '3196721.jpg', '218711.jpg', '1649276.jpg', '1008844.jpg', '1285298.jpg', '2121603.jpg', '1412034.jpg', '2885050.jpg', '2576168.jpg', '2190018.jpg', '2811032.jpg', '3530210.jpg', '2760984.jpg', '3338774.jpg', '667309.jpg', '3281494.jpg', '3699992.jpg', '2026009.jpg', '764429.jpg', '741883.jpg', '1633289.jpg', '138855.jpg', '3441394.jpg', '2785084.jpg', '5764.jpg', '715169.jpg', '702165.jpg', '2821048.jpg', '38349.jpg', '2330965.jpg', '2800325.jpg', '739735.jpg', '2228322.jpg', '244505.jpg', '3109486.jpg', '393658.jpg', '853441.jpg', '2992084.jpg', '1660415.jpg', '1899785.jpg', '3269634.jpg', '618348.jpg', '1105700.jpg', '1044789.jpg', '765799.jpg', '2154394.jpg', '3860002.jpg', '3018077.jpg', '1572608.jpg', '220190.jpg', '2493954.jpg', '2426686.jpg', '786995.jpg', '2428085.jpg', '3821701.jpg', '2702825.jpg', '68684.jpg', '2451169.jpg', '2285942.jpg', '12301.jpg', '1947572.jpg'])

# %%
for dir_path, dir_names, file_names in os.walk("data_food101/data"): # 지정된 디렉토리 내부를 거닐며("walk") 조회
    
    if len(dir_names) == 3:
        print('--------------------------------')
    
    print("There are {} directories and {} images in '{}'.".format(len(dir_names), len(file_names), dir_path))
# Out:
# There are 2 directories and 1 images in 'data_food101/data'.
# --------------------------------
# There are 3 directories and 0 images in 'data_food101/data/test'.
# There are 0 directories and 19 images in 'data_food101/data/test/steak'.
# There are 0 directories and 31 images in 'data_food101/data/test/sushi'.
# There are 0 directories and 25 images in 'data_food101/data/test/pizza'.
# --------------------------------
# There are 3 directories and 0 images in 'data_food101/data/train'.
# There are 0 directories and 75 images in 'data_food101/data/train/steak'.
# There are 0 directories and 72 images in 'data_food101/data/train/sushi'.
# There are 0 directories and 78 images in 'data_food101/data/train/pizza'.

# %%
TRAIN_DIR = "data_food101/data/train"
TEST_DIR  = "data_food101/data/test"

# %%
glob.glob("data_food101/data/train/*")
# Out:
# ['data_food101/data/train/steak',
#  'data_food101/data/train/sushi',
#  'data_food101/data/train/pizza']

# %%
glob.glob("data_food101/data/train/*/*.jpg")
# Out:
# ['data_food101/data/train/steak/239025.jpg',
#  'data_food101/data/train/steak/1598345.jpg',
#  'data_food101/data/train/steak/3074367.jpg',
#  'data_food101/data/train/steak/2979061.jpg',
#  'data_food101/data/train/steak/914570.jpg',
#  'data_food101/data/train/steak/167069.jpg',
#  'data_food101/data/train/steak/231296.jpg',
#  'data_food101/data/train/steak/2324994.jpg',
#  'data_food101/data/train/steak/2603058.jpg',
#  'data_food101/data/train/steak/1961025.jpg',
#  'data_food101/data/train/steak/1615395.jpg',
#  'data_food101/data/train/steak/2606444.jpg',
#  'data_food101/data/train/steak/355715.jpg',
#  'data_food101/data/train/steak/2163079.jpg',
#  'data_food101/data/train/steak/1736968.jpg',
#  'data_food101/data/train/steak/2878151.jpg',
#  'data_food101/data/train/steak/1976160.jpg',
#  'data_food101/data/train/steak/1382427.jpg',
#  'data_food101/data/train/steak/830007.jpg',
#  'data_food101/data/train/steak/256592.jpg',
#  'data_food101/data/train/steak/2561199.jpg',
#  'data_food101/data/train/steak/3142674.jpg',
#  'data_food101/data/train/steak/1966300.jpg',
#  'data_food101/data/train/steak/1225762.jpg',
#  'data_food101/data/train/steak/2287136.jpg',
#  'data_food101/data/train/steak/75537.jpg',
#  'data_food101/data/train/steak/461689.jpg',
#  'data_food101/data/train/steak/937133.jpg',
#  'data_food101/data/train/steak/2881783.jpg',
#  'data_food101/data/train/steak/443210.jpg',
#  'data_food101/data/train/steak/100135.jpg',
#  'data_food101/data/train/steak/735441.jpg',
#  'data_food101/data/train/steak/3727491.jpg',
#  'data_food101/data/train/steak/214320.jpg',
#  'data_food101/data/train/steak/339891.jpg',
#  'data_food101/data/train/steak/2129685.jpg',
#  'data_food101/data/train/steak/3518960.jpg',
#  'data_food101/data/train/steak/176508.jpg',
#  'data_food101/data/train/steak/1787505.jpg',
#  'data_food101/data/train/steak/3142045.jpg',
#  'data_food101/data/train/steak/2222018.jpg',
#  'data_food101/data/train/steak/3577618.jpg',
#  'data_food101/data/train/steak/2707522.jpg',
#  'data_food101/data/train/steak/2017387.jpg',
#  'data_food101/data/train/steak/2087958.jpg',
#  'data_food101/data/train/steak/2628106.jpg',
#  'data_food101/data/train/steak/2614189.jpg',
#  'data_food101/data/train/steak/2648423.jpg',
#  'data_food101/data/train/steak/2629750.jpg',
#  'data_food101/data/train/steak/165639.jpg',
#  'data_food101/data/train/steak/1257104.jpg',
#  'data_food101/data/train/steak/234626.jpg',
#  'data_food101/data/train/steak/1849463.jpg',
#  'data_food101/data/train/steak/421476.jpg',
#  'data_food101/data/train/steak/2013535.jpg',
#  'data_food101/data/train/steak/3245622.jpg',
#  'data_food101/data/train/steak/1761285.jpg',
#  'data_food101/data/train/steak/2614649.jpg',
#  'data_food101/data/train/steak/2880035.jpg',
#  'data_food101/data/train/steak/1647351.jpg',
#  'data_food101/data/train/steak/97656.jpg',
#  'data_food101/data/train/steak/1937872.jpg',
#  'data_food101/data/train/steak/922752.jpg',
#  'data_food101/data/train/steak/3727036.jpg',
#  'data_food101/data/train/steak/2254705.jpg',
#  'data_food101/data/train/steak/1624747.jpg',
#  'data_food101/data/train/steak/1413972.jpg',
#  'data_food101/data/train/steak/1621763.jpg',
#  'data_food101/data/train/steak/2825100.jpg',
#  'data_food101/data/train/steak/560503.jpg',
#  'data_food101/data/train/steak/225990.jpg',
#  'data_food101/data/train/steak/1839481.jpg',
#  'data_food101/data/train/steak/1264154.jpg',
#  'data_food101/data/train/steak/482022.jpg',
#  'data_food101/data/train/steak/3857508.jpg',
#  'data_food101/data/train/sushi/3081701.jpg',
#  'data_food101/data/train/sushi/17704.jpg',
#  'data_food101/data/train/sushi/1552504.jpg',
#  'data_food101/data/train/sushi/121940.jpg',
#  'data_food101/data/train/sushi/2813454.jpg',
#  'data_food101/data/train/sushi/748830.jpg',
#  'data_food101/data/train/sushi/3353428.jpg',
#  'data_food101/data/train/sushi/2873571.jpg',
#  'data_food101/data/train/sushi/840444.jpg',
#  'data_food101/data/train/sushi/3579071.jpg',
#  'data_food101/data/train/sushi/686426.jpg',
#  'data_food101/data/train/sushi/821108.jpg',
#  'data_food101/data/train/sushi/424994.jpg',
#  'data_food101/data/train/sushi/2574453.jpg',
#  'data_food101/data/train/sushi/3360232.jpg',
#  'data_food101/data/train/sushi/1551817.jpg',
#  'data_food101/data/train/sushi/1221830.jpg',
#  'data_food101/data/train/sushi/773725.jpg',
#  'data_food101/data/train/sushi/1232045.jpg',
#  'data_food101/data/train/sushi/1214108.jpg',
#  'data_food101/data/train/sushi/2720223.jpg',
#  'data_food101/data/train/sushi/385154.jpg',
#  'data_food101/data/train/sushi/765684.jpg',
#  'data_food101/data/train/sushi/148799.jpg',
#  'data_food101/data/train/sushi/169392.jpg',
#  'data_food101/data/train/sushi/14046.jpg',
#  'data_food101/data/train/sushi/710379.jpg',
#  'data_food101/data/train/sushi/1615453.jpg',
#  'data_food101/data/train/sushi/794647.jpg',
#  'data_food101/data/train/sushi/1575445.jpg',
#  'data_food101/data/train/sushi/2797464.jpg',
#  'data_food101/data/train/sushi/497686.jpg',
#  'data_food101/data/train/sushi/2641778.jpg',
#  'data_food101/data/train/sushi/93139.jpg',
#  'data_food101/data/train/sushi/3251688.jpg',
#  'data_food101/data/train/sushi/1571146.jpg',
#  'data_food101/data/train/sushi/1280119.jpg',
#  'data_food101/data/train/sushi/2004525.jpg',
#  'data_food101/data/train/sushi/2590819.jpg',
#  'data_food101/data/train/sushi/700405.jpg',
#  'data_food101/data/train/sushi/170385.jpg',
#  'data_food101/data/train/sushi/929471.jpg',
#  'data_food101/data/train/sushi/2871052.jpg',
#  'data_food101/data/train/sushi/2492146.jpg',
#  'data_food101/data/train/sushi/2017378.jpg',
#  'data_food101/data/train/sushi/3004029.jpg',
#  'data_food101/data/train/sushi/200025.jpg',
#  'data_food101/data/train/sushi/1129338.jpg',
#  'data_food101/data/train/sushi/2019344.jpg',
#  'data_food101/data/train/sushi/1209865.jpg',
#  'data_food101/data/train/sushi/2021381.jpg',
#  'data_food101/data/train/sushi/1957449.jpg',
#  'data_food101/data/train/sushi/377047.jpg',
#  'data_food101/data/train/sushi/390178.jpg',
#  'data_food101/data/train/sushi/1070104.jpg',
#  'data_food101/data/train/sushi/2267190.jpg',
#  'data_food101/data/train/sushi/268990.jpg',
#  'data_food101/data/train/sushi/2323548.jpg',
#  'data_food101/data/train/sushi/542188.jpg',
#  'data_food101/data/train/sushi/1138695.jpg',
#  'data_food101/data/train/sushi/3426958.jpg',
#  'data_food101/data/train/sushi/307738.jpg',
#  'data_food101/data/train/sushi/2980779.jpg',
#  'data_food101/data/train/sushi/2175561.jpg',
#  'data_food101/data/train/sushi/843815.jpg',
#  'data_food101/data/train/sushi/2021685.jpg',
#  'data_food101/data/train/sushi/2674024.jpg',
#  'data_food101/data/train/sushi/3360207.jpg',
#  'data_food101/data/train/sushi/855721.jpg',
#  'data_food101/data/train/sushi/2120573.jpg',
#  'data_food101/data/train/sushi/3107839.jpg',
#  'data_food101/data/train/sushi/3737197.jpg',
#  'data_food101/data/train/pizza/1033251.jpg',
#  'data_food101/data/train/pizza/29417.jpg',
#  'data_food101/data/train/pizza/928670.jpg',
#  'data_food101/data/train/pizza/1968947.jpg',
#  'data_food101/data/train/pizza/300869.jpg',
#  'data_food101/data/train/pizza/2885796.jpg',
#  'data_food101/data/train/pizza/2291093.jpg',
#  'data_food101/data/train/pizza/1089334.jpg',
#  'data_food101/data/train/pizza/3589437.jpg',
#  'data_food101/data/train/pizza/3505182.jpg',
#  'data_food101/data/train/pizza/1524655.jpg',
#  'data_food101/data/train/pizza/1654444.jpg',
#  'data_food101/data/train/pizza/2569760.jpg',
#  'data_food101/data/train/pizza/2924941.jpg',
#  'data_food101/data/train/pizza/2687575.jpg',
#  'data_food101/data/train/pizza/2382016.jpg',
#  'data_food101/data/train/pizza/320570.jpg',
#  'data_food101/data/train/pizza/3196721.jpg',
#  'data_food101/data/train/pizza/218711.jpg',
#  'data_food101/data/train/pizza/1649276.jpg',
#  'data_food101/data/train/pizza/1008844.jpg',
#  'data_food101/data/train/pizza/1285298.jpg',
#  'data_food101/data/train/pizza/2121603.jpg',
#  'data_food101/data/train/pizza/1412034.jpg',
#  'data_food101/data/train/pizza/2885050.jpg',
#  'data_food101/data/train/pizza/2576168.jpg',
#  'data_food101/data/train/pizza/2190018.jpg',
#  'data_food101/data/train/pizza/2811032.jpg',
#  'data_food101/data/train/pizza/3530210.jpg',
#  'data_food101/data/train/pizza/2760984.jpg',
#  'data_food101/data/train/pizza/3338774.jpg',
#  'data_food101/data/train/pizza/667309.jpg',
#  'data_food101/data/train/pizza/3281494.jpg',
#  'data_food101/data/train/pizza/3699992.jpg',
#  'data_food101/data/train/pizza/2026009.jpg',
#  'data_food101/data/train/pizza/764429.jpg',
#  'data_food101/data/train/pizza/741883.jpg',
#  'data_food101/data/train/pizza/1633289.jpg',
#  'data_food101/data/train/pizza/138855.jpg',
#  'data_food101/data/train/pizza/3441394.jpg',
#  'data_food101/data/train/pizza/2785084.jpg',
#  'data_food101/data/train/pizza/5764.jpg',
#  'data_food101/data/train/pizza/715169.jpg',
#  'data_food101/data/train/pizza/702165.jpg',
#  'data_food101/data/train/pizza/2821048.jpg',
#  'data_food101/data/train/pizza/38349.jpg',
#  'data_food101/data/train/pizza/2330965.jpg',
#  'data_food101/data/train/pizza/2800325.jpg',
#  'data_food101/data/train/pizza/739735.jpg',
#  'data_food101/data/train/pizza/2228322.jpg',
#  'data_food101/data/train/pizza/244505.jpg',
#  'data_food101/data/train/pizza/3109486.jpg',
#  'data_food101/data/train/pizza/393658.jpg',
#  'data_food101/data/train/pizza/853441.jpg',
#  'data_food101/data/train/pizza/2992084.jpg',
#  'data_food101/data/train/pizza/1660415.jpg',
#  'data_food101/data/train/pizza/1899785.jpg',
#  'data_food101/data/train/pizza/3269634.jpg',
#  'data_food101/data/train/pizza/618348.jpg',
#  'data_food101/data/train/pizza/1105700.jpg',
#  'data_food101/data/train/pizza/1044789.jpg',
#  'data_food101/data/train/pizza/765799.jpg',
#  'data_food101/data/train/pizza/2154394.jpg',
#  'data_food101/data/train/pizza/3860002.jpg',
#  'data_food101/data/train/pizza/3018077.jpg',
#  'data_food101/data/train/pizza/1572608.jpg',
#  'data_food101/data/train/pizza/220190.jpg',
#  'data_food101/data/train/pizza/2493954.jpg',
#  'data_food101/data/train/pizza/2426686.jpg',
#  'data_food101/data/train/pizza/786995.jpg',
#  'data_food101/data/train/pizza/2428085.jpg',
#  'data_food101/data/train/pizza/3821701.jpg',
#  'data_food101/data/train/pizza/2702825.jpg',
#  'data_food101/data/train/pizza/68684.jpg',
#  'data_food101/data/train/pizza/2451169.jpg',
#  'data_food101/data/train/pizza/2285942.jpg',
#  'data_food101/data/train/pizza/12301.jpg',
#  'data_food101/data/train/pizza/1947572.jpg']

# %%
train_images = glob.glob("data_food101/data/train/*/*.jpg")

sample_image = random.choice(train_images)

sample_image
# Out:
# 'data_food101/data/train/steak/256592.jpg'

# %%
from PIL import Image

img = Image.open(sample_image)

print(img.height)
print(img.width)

img
# Out:
# 384
# 512
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=512x384>

# %%
img = Image.open(sample_image)

# Should change an image file into a "numpy array" first to use "plt.imshow()"
img_array = np.array(img)

print(img_array.shape)

plt.figure(figsize=(10, 7))

plt.imshow(img_array)
# Out:
# (384, 512, 3)

# %% [markdown]
# <br>
# <br>
#
# # 2. Prepare the **DataLoader** - Using [ torchvision.datasets.**ImageFolder** ]

# %% [markdown]
# ### 1) prepare the image-transformation (**Resize** & **ToTensor**)

# %%
# from torchvision import transforms

# %%
# torchvision.transforms.ToTensor()는 pixel 값들을 [ 0~255 ] 에서 [ 0.0~1.0 ]으로 자동 변환합니다. @ https://bit.ly/3gpqIn0

IMG_TRANSFORM = transforms.Compose([ # "구성하다"(compose)
    
    transforms.Resize(size=(64, 64)), # image resize
    transforms.ToTensor() # (Original) PIL format -> PyTorch tensors 

])

# %% [markdown]
# ### 2) **image directories** -> **ImageFolder** (with image-transformation)

# %%
# from torchvision.datasets import ImageFolder

# %%
train_imgfolder = ImageFolder(root=TRAIN_DIR,
                              transform=IMG_TRANSFORM, # torchvision.transforms.Compose
                              target_transform=None)   # we can transform labels, too (if it is needed)

test_imgfolder  = ImageFolder(root=TEST_DIR,
                              transform=IMG_TRANSFORM)

print(train_imgfolder, '\n')
print(test_imgfolder)
# Out:
# Dataset ImageFolder
#     Number of datapoints: 225
#     Root location: data_food101/data/train
#     StandardTransform
# Transform: Compose(
#                Resize(size=(64, 64), interpolation=bilinear, max_size=None, antialias=warn)
#                ToTensor()
#            )
#
# Dataset ImageFolder
#     Number of datapoints: 75
#     Root location: data_food101/data/test
#     StandardTransform
# Transform: Compose(
#                Resize(size=(64, 64), interpolation=bilinear, max_size=None, antialias=warn)
#                ToTensor()
#            )

# %%
train_imgfolder.classes # automatically extracted from the names of directories
# Out:
# ['pizza', 'steak', 'sushi']

# %%
len(train_imgfolder)
# Out:
# 225

# %%
train_imgfolder[0]
# Out:
# (tensor([[[0.1176, 0.1216, 0.1255,  ..., 0.0980, 0.1020, 0.1137],
#           [0.1294, 0.1294, 0.1294,  ..., 0.0980, 0.0980, 0.1059],
#           [0.1333, 0.1333, 0.1333,  ..., 0.0941, 0.0980, 0.1020],
#           ...,
#           [0.1686, 0.1647, 0.1686,  ..., 0.1255, 0.1098, 0.1098],
#           [0.1686, 0.1647, 0.1686,  ..., 0.1098, 0.0941, 0.0863],
#           [0.1647, 0.1647, 0.1686,  ..., 0.0980, 0.0863, 0.0863]],
#
#          [[0.0588, 0.0588, 0.0588,  ..., 0.0745, 0.0706, 0.0745],
#           [0.0627, 0.0627, 0.0627,  ..., 0.0745, 0.0706, 0.0706],
#           [0.0706, 0.0706, 0.0706,  ..., 0.0745, 0.0745, 0.0706],
#           ...,
#           [0.2392, 0.2392, 0.2510,  ..., 0.1373, 0.1333, 0.1255],
#           [0.2314, 0.2392, 0.2510,  ..., 0.1255, 0.1176, 0.1098],
#           [0.2275, 0.2353, 0.2431,  ..., 0.1137, 0.1059, 0.1020]],
#
#          [[0.0196, 0.0196, 0.0196,  ..., 0.0902, 0.0902, 0.0941],
#           [0.0196, 0.0157, 0.0196,  ..., 0.0902, 0.0863, 0.0902],
#           [0.0196, 0.0157, 0.0157,  ..., 0.0902, 0.0902, 0.0902],
#           ...,
#           [0.1804, 0.1882, 0.1961,  ..., 0.1490, 0.1333, 0.1294],
#           [0.1804, 0.1843, 0.1922,  ..., 0.1255, 0.1137, 0.1098],
#           [0.1765, 0.1804, 0.1843,  ..., 0.1059, 0.1020, 0.1059]]]),
#  0)

# %%
train_imgfolder.class_to_idx
# Out:
# {'pizza': 0, 'steak': 1, 'sushi': 2}

# %%
img   = train_imgfolder[0][0]
label = train_imgfolder[0][1]

# %%
print(type(img))
print(img.shape) # after the data-augmentation
print(img.dtype)
print(label)

plt.imshow(img.permute(1, 2, 0)) # tensor.permute(1, 2, 0) : [ Channels, Height, Width ] -> [ Height, Width, Channels ]
plt.axis("off")
plt.show()
# Out:
# <class 'torch.Tensor'>
# torch.Size([3, 64, 64])
# torch.float32
# 0

# %% [markdown]
# ### 3) (**image directories** ->) **ImageFolder** -> **DataLoader** (iterable for mini-batches)

# %%
# from torch.utils.data import DataLoader

# %%
os.cpu_count() # the total number of CPUs on the current machine
# Out:
# 8

# %%
torch.manual_seed(42)

train_dataloader = DataLoader(dataset=train_imgfolder, 
                              batch_size=32, 
                              num_workers=os.cpu_count(), # number of subprocesses to use for data loading
                              shuffle=True)

test_dataloader  = DataLoader(dataset=test_imgfolder, 
                              batch_size=32, 
                              num_workers=os.cpu_count(), 
                              shuffle=False) # 테스트 데이터는 shuffling할 필요가 없습니다.

# %%
# A set of batch-data

batch_x, batch_y = next(iter(train_dataloader))

# %%
batch_x.shape
# Out:
# torch.Size([32, 3, 64, 64])

# %%
batch_y.shape
# Out:
# torch.Size([32])

# %%
image_sample = batch_x[0]

print(type(image_sample))
print(image_sample.shape) # after the data-augmentation
print(image_sample.dtype)

plt.imshow(image_sample.permute(1, 2, 0))
plt.axis("off")
plt.show()
# Out:
# <class 'torch.Tensor'>
# torch.Size([3, 64, 64])
# torch.float32

# %% [markdown]
# <br>
# <br>
#
# # 3. Build the model - CNN **without** data-augmentation

# %%
class CNN_TinyVGG(nn.Module): # should inherit the class nn.Module
    
    
    def __init__(self, num_channels, num_filters, num_classes): 
        
        super().__init__()
        
        
        self.conv_block_entrance = nn.Sequential( # Create a sequential model
            
            # Convolution-layer
            nn.Conv2d(in_channels=num_channels, # will be '3' == R/G/B
                      out_channels=num_filters, # num_filters == num of feature-maps == num of output channels
                      kernel_size=(3, 3), 
                      stride=1,     # default
                      padding=1),   # 0 == 'valid', 1 == 'same' 
            nn.ReLU(),
            
            # Convolution-layer
            nn.Conv2d(in_channels=num_filters,  # should be same as the number of "channels of previous output"
                      out_channels=num_filters,
                      kernel_size=(3, 3),
                      stride=1,
                      padding=1),
            nn.ReLU(),
            
            # Pooling-layer
            nn.MaxPool2d(kernel_size=2, stride=2) # "stride" Default == kernel_size (자동으로 지정됨)
        )
        # [ 32, 3, 64, 64 ] -> [ 32, 10, 32, 32 ]
        
        
        self.conv_block_within = nn.Sequential(
            nn.Conv2d(num_filters, num_filters, (3, 3), padding=1),
            nn.ReLU(),
            nn.Conv2d(num_filters, num_filters, (3, 3), padding=1),
            nn.ReLU(),
            nn.MaxPool2d(2) # 이때 사이즈의 변경이 이루어 진다
        )
        # [ 32, 10, 32, 32 ] -> [ 32, 10, 16, 16 ]
        
        
        self.classifier_block = nn.Sequential(
            nn.Flatten(), # Flatten the input data
            nn.Linear(in_features=num_filters * 16 * 16, 
                      out_features=num_classes)
        )
        # [ 32, 10, 16, 16 ] -> [ 32, 10 * 16 * 16 ] -> [ 32, 10 ]
    
    
    def forward(self, x):
        
        x = self.conv_block_entrance(x)
#         print(x.shape)
        
        x = self.conv_block_within(x)
#         print(x.shape)
        
        x = self.classifier_block(x)
#         print(x.shape)
        
        # 아래와 같이 코드를 작성하게되면 메모리가 크게 소요되는 변수 재할당 과정이 생략되므로 계산 속도가 향상됩니다. (https://bit.ly/3V16ZJy)
        # return self.classifier_block(conv_block_within(conv_block_entrance(x)))
        
        return x

# %% [markdown]
# <br>
# <br>
#
# # 4.  Train the model

# %%
device = "cuda" if torch.cuda.is_available() else "cpu" # "cuda"가 사용 가능하다면 (if it "is available")

device
# Out:
# 'cpu'

# %% [markdown]
# <br>
#
# ### 1) Initialize the model

# %%
torch.manual_seed(42) # "Manually" set the "seed"

model = CNN_TinyVGG(num_channels=3, # R / G / B
                    num_filters=10, # number of filters == number of feature-maps
                    num_classes=3   # Pizza / Steak / Sushi
                   ).to(device)
    
model
# Out:
# CNN_TinyVGG(
#   (conv_block_entrance): Sequential(
#     (0): Conv2d(3, 10, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU()
#     (2): Conv2d(10, 10, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (3): ReLU()
#     (4): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (conv_block_within): Sequential(
#     (0): Conv2d(10, 10, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU()
#     (2): Conv2d(10, 10, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (3): ReLU()
#     (4): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (classifier_block): Sequential(
#     (0): Flatten(start_dim=1, end_dim=-1)
#     (1): Linear(in_features=2560, out_features=3, bias=True)
#   )
# )

# %%
# # 모델 내에서의 Shape 변화를 확인하고 싶을 경우 forward 함수 내 주석 해제 후 아래 코드를 실행해주세요.

temp_batch_x = next(iter(train_dataloader))[0]

print(temp_batch_x.shape)

model(temp_batch_x)
# Out:
# torch.Size([32, 3, 64, 64])
# torch.Size([32, 10, 32, 32])
# torch.Size([32, 10, 16, 16])
# torch.Size([32, 3])
# tensor([[0.0578, 0.0634, 0.0352],
#         [0.0658, 0.0650, 0.0398],
#         [0.0702, 0.0678, 0.0412],
#         [0.0687, 0.0646, 0.0417],
#         [0.0625, 0.0613, 0.0355],
#         [0.0587, 0.0595, 0.0358],
#         [0.0634, 0.0637, 0.0375],
#         [0.0653, 0.0615, 0.0376],
#         [0.0678, 0.0621, 0.0348],
#         [0.0620, 0.0599, 0.0370],
#         [0.0607, 0.0628, 0.0387],
#         [0.0637, 0.0589, 0.0352],
#         [0.0658, 0.0611, 0.0369],
#         [0.0703, 0.0690, 0.0330],
#         [0.0557, 0.0570, 0.0357],
#         [0.0631, 0.0642, 0.0388],
#         [0.0639, 0.0616, 0.0375],
#         [0.0605, 0.0600, 0.0374],
#         [0.0623, 0.0627, 0.0369],
#         [0.0740, 0.0676, 0.0400],
#         [0.0621, 0.0613, 0.0361],
#         [0.0632, 0.0599, 0.0366],
#         [0.0662, 0.0627, 0.0334],
#         [0.0638, 0.0622, 0.0394],
#         [0.0670, 0.0666, 0.0363],
#         [0.0650, 0.0601, 0.0405],
#         [0.0639, 0.0597, 0.0395],
#         [0.0733, 0.0687, 0.0412],
#         [0.0697, 0.0631, 0.0402],
#         [0.0625, 0.0602, 0.0442],
#         [0.0609, 0.0591, 0.0368],
#         [0.0571, 0.0564, 0.0333]], grad_fn=<AddmmBackward0>)

# %% [markdown]
# <br>
#
# ### 2) Check the model before training

# %%
# batch_x, batch_y = next(iter(train_dataloader))

sample_label = batch_y[0]

sample_img = batch_x[0]
print(sample_img.shape)

sample_img = sample_img.reshape(1, 3, 64, 64)
print(sample_img.shape, '\n')

    
# 모델을 evaluation mode로 설정
model.eval()

with torch.inference_mode(): # Set "inference mode"
    logits = model(sample_img.to(device))

    
print(logits)

print(logits.softmax(dim=1)) # 행 방향 Softmax 적용

print(logits.softmax(dim=1).argmax(dim=1)[0]) # 행 방향 Softmax & argmax 적용

print(sample_label)
# Out:
# torch.Size([3, 64, 64])
# torch.Size([1, 3, 64, 64])
#
# torch.Size([1, 10, 32, 32])
# torch.Size([1, 10, 16, 16])
# torch.Size([1, 3])
# tensor([[0.0657, 0.0651, 0.0391]])
# tensor([[0.3363, 0.3361, 0.3275]])
# tensor(0)
# tensor(2)

# %%
# !pip install torchinfo 
# 1.7.1
# Out:
# Collecting torchinfo
#   Downloading torchinfo-1.8.0-py3-none-any.whl (23 kB)
# Installing collected packages: torchinfo
# Successfully installed torchinfo-1.8.0

# %%
from torchinfo import summary  # 요약

summary(model, input_size=[32, 3, 64, 64])
# Out:
# torch.Size([32, 10, 32, 32])
# torch.Size([32, 10, 16, 16])
# torch.Size([32, 3])
# ==========================================================================================
# Layer (type:depth-idx)                   Output Shape              Param #
# ==========================================================================================
# CNN_TinyVGG                              [32, 3]                   --
# ├─Sequential: 1-1                        [32, 10, 32, 32]          --
# │    └─Conv2d: 2-1                       [32, 10, 64, 64]          280
# │    └─ReLU: 2-2                         [32, 10, 64, 64]          --
# │    └─Conv2d: 2-3                       [32, 10, 64, 64]          910
# │    └─ReLU: 2-4                         [32, 10, 64, 64]          --
# │    └─MaxPool2d: 2-5                    [32, 10, 32, 32]          --
# ├─Sequential: 1-2                        [32, 10, 16, 16]          --
# │    └─Conv2d: 2-6                       [32, 10, 32, 32]          910
# │    └─ReLU: 2-7                         [32, 10, 32, 32]          --
# │    └─Conv2d: 2-8                       [32, 10, 32, 32]          910
# │    └─ReLU: 2-9                         [32, 10, 32, 32]          --
# │    └─MaxPool2d: 2-10                   [32, 10, 16, 16]          --
# ├─Sequential: 1-3                        [32, 3]                   --
# │    └─Flatten: 2-11                     [32, 2560]                --
# │    └─Linear: 2-12                      [32, 3]                   7,683
# ==========================================================================================
# Total params: 10,693
# Trainable params: 10,693
# Non-trainable params: 0
# Total mult-adds (Units.MEGABYTES): 215.86
# ==========================================================================================
# Input size (MB): 1.57
# Forward/backward pass size (MB): 26.22
# Params size (MB): 0.04
# Estimated Total Size (MB): 27.83
# ==========================================================================================

# %% [markdown]
# <br>
#
# ### 3) Make train & test step as separate functions

# %%
def train_step(model, dataloader, loss_fn, optimizer, metric, device):
    
    # 모델을 training mode로 설정 (default state)
    model.train()
    
    # train-loss & train-accuracy for one epoch
    train_loss = 0
    train_acc  = 0
    
    for batch_idx, (X, y) in enumerate(dataloader): # get an item from DataLoader with it's index number
        
        X = X.to(device)
        y = y.to(device)
        
        # 1. (x 데이터를 모델에 넣고) 순방향 계산 진행 (forward pass)
        logits = model(X)

        # 2. (Batch) Training cost 계산 (Cost function 계산)
        loss = loss_fn(logits, y) # cost of batch <- nn.CrossEntropyLoss() : built-in Softmax
        train_loss += loss.item()
        
        # 3. Optimizer 내부의 이전 gradient 값 초기화 (Make "grad" to "zero")
        optimizer.zero_grad()

        # 4. Back-propagation ("Backward" propagation)
        loss.backward()

        # 5. Gradient descent 진행 (Take a "step" to update parameters)
        optimizer.step()

        # 6. (Batch) Training accuracy 계산 
        predicted_classes = logits.softmax(dim=1).argmax(dim=1)
        train_acc += metric(predicted_classes, y).item() # calculate the batch accuracy & add to the epoch accuracy

    
    # Batch 순회 종료 후
    train_loss = train_loss / len(dataloader) # cost of batches / num of batches (calculate average)
    train_acc  = train_acc  / len(dataloader) # acc  of batches / num of batches (calculate average)
    
    return train_loss, train_acc

# %%
def test_step(model, dataloader, loss_fn, metric, device):
    
    # 모델을 evaluation mode로 설정
    model.eval() 
    
    # test-loss & test-accuracy for one epoch
    test_loss = 0
    test_acc  = 0
    
    with torch.inference_mode(): # Set "inference mode"
        
        for batch_idx, (X, y) in enumerate(dataloader): # get an item from DataLoader with it's index number
            
            X = X.to(device)
            y = y.to(device)
    
            # 1. (x 데이터를 모델에 넣고) 순방향 계산 진행 (forward pass)
            logits = model(X)

            # 2. (Batch) Test cost 계산 (Cost function 계산)
            loss = loss_fn(logits, y) # cost of batch <- nn.CrossEntropyLoss() : built-in Softmax
            test_loss += loss.item()

            # 3. (Batch) Test accuracy 계산 
            predicted_classes = logits.softmax(dim=1).argmax(dim=1)
            test_acc += metric(predicted_classes, y).item() # calculate the batch accuracy & add to the epoch accuracy

    
    # Batch 순회 종료 후
    test_loss = test_loss / len(dataloader) # cost of batches / num of batches (calculate average)
    test_acc  = test_acc  / len(dataloader) # acc  of batches / num of batches (calculate average)
    
    return test_loss, test_acc

# %% [markdown]
# <br>
#
# ### 4) Combine train & test step into a simplified "train" function

# %%
def train(model, 
          train_dataloader, test_dataloader, 
          optimizer, loss_fn, metric, 
          device, epochs=5):
    
    
    results = {"train_loss": [], 
               "train_acc" : [], 
               "test_loss" : [], 
               "test_acc"  : []}
    
    
    for epoch in tqdm(range(epochs)): # from tqdm.auto import tqdm
        
        train_loss, train_acc = train_step(model=model,
                                           dataloader=train_dataloader,
                                           loss_fn=loss_fn, 
                                           optimizer=optimizer, 
                                           metric=metric, 
                                           device=device)
        
        test_loss, test_acc   = test_step(model=model,
                                          dataloader=test_dataloader, 
                                          loss_fn=loss_fn, 
                                          metric=metric, 
                                          device=device)
        
        
        results["train_loss"].append(train_loss)
        results["train_acc"].append(train_acc)
        results["test_loss"].append(test_loss)
        results["test_acc"].append(test_acc)
        
        
        print('Epoch : {} | Train_loss : {} | Train_acc : {} | Test_loss : {} | Test_acc : {}'.format(epoch+1, 
                                                                                                      train_loss, 
                                                                                                      train_acc, 
                                                                                                      test_loss, 
                                                                                                      test_acc))
    
    return results

# %% [markdown]
# <br>
#
# ### 5) Train the model & Check the result

# %%
torch.manual_seed(42) 

model = CNN_TinyVGG(num_channels=3, # R / G / B
                    num_filters=10, # number of filters == number of feature-maps
                    num_classes=3   # Pizza / Steak / Sushi <- len(train_data.classes)
                   ).to(device)

# %%
loss_fn = nn.CrossEntropyLoss() # Softmax + CrossEntropy (built-in Softmax)

optimizer = torch.optim.Adam(params=model.parameters(), # "parameters" to optimize (apply gradient descent)
                             lr=0.001)                  # "l"earning "r"ate 
    
metric_accuracy = Accuracy(task='multiclass',num_classes=3).to(device) # from torchmetrics import Accuracy

# %%
from timeit import default_timer as timer 

START_TIME = timer()

NUM_EPOCHS = 10

model_results = train(model=model, 
                      train_dataloader=train_dataloader,
                      test_dataloader=test_dataloader,
                      optimizer=optimizer,
                      loss_fn=loss_fn, 
                      metric=metric_accuracy,
                      device=device,
                      epochs=NUM_EPOCHS)

END_TIME = timer()
# Out:
#   0%|          | 0/10 [00:00<?, ?it/s]
# torch.Size([32, 10, 32, 32])
# torch.Size([32, 10, 16, 16])
# torch.Size([32, 3])
# torch.Size([32, 10, 32, 32])
# torch.Size([32, 10, 16, 16])
# torch.Size([32, 3])
# torch.Size([32, 10, 32, 32])
# torch.Size([32, 10, 16, 16])
# torch.Size([32, 3])
# torch.Size([32, 10, 32, 32])
# torch.Size([32, 10, 16, 16])
# torch.Size([32, 3])
# torch.Size([32, 10, 32, 32])
# torch.Size([32, 10, 16, 16])
# torch.Size([32, 3])
# torch.Size([32, 10, 32, 32])
# torch.Size([32, 10, 16, 16])
# torch.Size([32, 3])
# torch.Size([32, 10, 32, 32])
# torch.Size([32, 10, 16, 16])
# torch.Size([32, 3])
# torch.Size([1, 10, 32, 32])
# torch.Size([1, 10, 16, 16])
# torch.Size([1, 3])
# torch.Size([32, 10, 32, 32])
# torch.Size([32, 10, 16, 16])
# torch.Size([32, 3])
# torch.Size([32, 10, 32, 32])
# torch.Size([32, 10, 16, 16])
# torch.Size([32, 3])
# torch.Size([11, 10, 32, 32])
# torch.Size([11, 10, 16, 16])
# torch.Size([11, 3])
# Epoch : 1 | Train_loss : 1.1078328043222427 | Train_acc : 0.2578125 | Test_loss : 1.136040727297465 | Test_acc : 0.2604166666666667
# torch.Size([32, 10, 32, 32])
# torch.Size([32, 10, 16, 16])
# torch.Size([32, 3])
# torch.Size([32, 10, 32, 32])
# torch.Size([32, 10, 16, 16])
# torch.Size([32, 3])
# torch.Size([32, 10, 32, 32])
# torch.Size([32, 10, 16, 16])
# torch.Size([32, 3])
# torch.Size([32, 10, 32, 32])
# torch.Size([32, 10, 16, 16])
# torch.Size([32, 3])
# torch.Size([32, 10, 32, 32])
# torch.Size([32, 10, 16, 16])
# torch.Size([32, 3])
# torch.Size([32, 10, 32, 32])
# torch.Size([32, 10, 16, 16])
# torch.Size([32, 3])
# torch.Size([32, 10, 32, 32])
# torch.Size([32, 10, 16, 16])
# torch.Size([32, 3])
# torch.Size([1, 10, 32, 32])
# torch.Size([1, 10, 16, 16])
# torch.Size([1, 3])
# torch.Size([32, 10, 32, 32])
# torch.Size([32, 10, 16, 16])
# torch.Size([32, 3])
# torch.Size([32, 10, 32, 32])
# torch.Size([32, 10, 16, 16])
# torch.Size([32, 3])
# torch.Size([11, 10, 32, 32])
# torch.Size([11, 10, 16, 16])
# torch.Size([11, 3])
# Epoch : 2 | Train_loss : 1.0847121551632881 | Train_acc : 0.42578125 | Test_loss : 1.1620184183120728 | Test_acc : 0.19791666666666666
# torch.Size([32, 10, 32, 32])
# torch.Size([32, 10, 16, 16])
# torch.Size([32, 3])
# torch.Size([32, 10, 32, 32])
# torch.Size([32, 10, 16, 16])
# torch.Size([32, 3])
# torch.Size([32, 10, 32, 32])
# torch.Size([32, 10, 16, 16])
# torch.Size([32, 3])
# torch.Size([32, 10, 32, 32])
# torch.Size([32, 10, 16, 16])
# torch.Size([32, 3])
# torch.Size([32, 10, 32, 32])
# torch.Size([32, 10, 16, 16])
# torch.Size([32, 3])
# torch.Size([32, 10, 32, 32])
# torch.Size([32, 10, 16, 16])
# torch.Size([32, 3])
# torch.Size([32, 10, 32, 32])
# torch.Size([32, 10, 16, 16])
# torch.Size([32, 3])
# torch.Size([1, 10, 32, 32])
# torch.Size([1, 10, 16, 16])
# torch.Size([1, 3])
# torch.Size([32, 10, 32, 32])
# torch.Size([32, 10, 16, 16])
# torch.Size([32, 3])
# torch.Size([32, 10, 32, 32])
# torch.Size([32, 10, 16, 16])
# torch.Size([32, 3])
# torch.Size([11, 10, 32, 32])
# torch.Size([11, 10, 16, 16])
# torch.Size([11, 3])
# Epoch : 3 | Train_loss : 1.1156915873289108 | Train_acc : 0.29296875 | Test_loss : 1.1696898142496746 | Test_acc : 0.19791666666666666
# torch.Size([32, 10, 32, 32])
# torch.Size([32, 10, 16, 16])
# torch.Size([32, 3])
# torch.Size([32, 10, 32, 32])
# torch.Size([32, 10, 16, 16])
# torch.Size([32, 3])
# torch.Size([32, 10, 32, 32])
# torch.Size([32, 10, 16, 16])
# torch.Size([32, 3])
# torch.Size([32, 10, 32, 32])
# torch.Size([32, 10, 16, 16])
# torch.Size([32, 3])
# torch.Size([32, 10, 32, 32])
# torch.Size([32, 10, 16, 16])
# torch.Size([32, 3])
# torch.Size([32, 10, 32, 32])
# torch.Size([32, 10, 16, 16])
# torch.Size([32, 3])
# torch.Size([32, 10, 32, 32])
# torch.Size([32, 10, 16, 16])
# torch.Size([32, 3])
# torch.Size([1, 10, 32, 32])
# torch.Size([1, 10, 16, 16])
# torch.Size([1, 3])
# torch.Size([32, 10, 32, 32])
# torch.Size([32, 10, 16, 16])
# torch.Size([32, 3])
# torch.Size([32, 10, 32, 32])
# torch.Size([32, 10, 16, 16])
# torch.Size([32, 3])
# torch.Size([11, 10, 32, 32])
# torch.Size([11, 10, 16, 16])
# torch.Size([11, 3])
# Epoch : 4 | Train_loss : 1.0955415070056915 | Train_acc : 0.4140625 | Test_loss : 1.1384695370992024 | Test_acc : 0.19791666666666666
# torch.Size([32, 10, 32, 32])
# torch.Size([32, 10, 16, 16])
# torch.Size([32, 3])
# torch.Size([32, 10, 32, 32])
# torch.Size([32, 10, 16, 16])
# torch.Size([32, 3])
# torch.Size([32, 10, 32, 32])
# torch.Size([32, 10, 16, 16])
# torch.Size([32, 3])
# torch.Size([32, 10, 32, 32])
# torch.Size([32, 10, 16, 16])
# torch.Size([32, 3])
# torch.Size([32, 10, 32, 32])
# torch.Size([32, 10, 16, 16])
# torch.Size([32, 3])
# torch.Size([32, 10, 32, 32])
# torch.Size([32, 10, 16, 16])
# torch.Size([32, 3])
# torch.Size([32, 10, 32, 32])
# torch.Size([32, 10, 16, 16])
# torch.Size([32, 3])
# torch.Size([1, 10, 32, 32])
# torch.Size([1, 10, 16, 16])
# torch.Size([1, 3])
# torch.Size([32, 10, 32, 32])
# torch.Size([32, 10, 16, 16])
# torch.Size([32, 3])
# torch.Size([32, 10, 32, 32])
# torch.Size([32, 10, 16, 16])
# torch.Size([32, 3])
# torch.Size([11, 10, 32, 32])
# torch.Size([11, 10, 16, 16])
# torch.Size([11, 3])
# Epoch : 5 | Train_loss : 1.0985173732042313 | Train_acc : 0.29296875 | Test_loss : 1.142745574315389 | Test_acc : 0.19791666666666666
# torch.Size([32, 10, 32, 32])
# torch.Size([32, 10, 16, 16])
# torch.Size([32, 3])
# torch.Size([32, 10, 32, 32])
# torch.Size([32, 10, 16, 16])
# torch.Size([32, 3])
# torch.Size([32, 10, 32, 32])
# torch.Size([32, 10, 16, 16])
# torch.Size([32, 3])
# torch.Size([32, 10, 32, 32])
# torch.Size([32, 10, 16, 16])
# torch.Size([32, 3])
# torch.Size([32, 10, 32, 32])
# torch.Size([32, 10, 16, 16])
# torch.Size([32, 3])
# torch.Size([32, 10, 32, 32])
# torch.Size([32, 10, 16, 16])
# torch.Size([32, 3])
# torch.Size([32, 10, 32, 32])
# torch.Size([32, 10, 16, 16])
# torch.Size([32, 3])
# torch.Size([1, 10, 32, 32])
# torch.Size([1, 10, 16, 16])
# torch.Size([1, 3])
# torch.Size([32, 10, 32, 32])
# torch.Size([32, 10, 16, 16])
# torch.Size([32, 3])
# torch.Size([32, 10, 32, 32])
# torch.Size([32, 10, 16, 16])
# torch.Size([32, 3])
# torch.Size([11, 10, 32, 32])
# torch.Size([11, 10, 16, 16])
# torch.Size([11, 3])
# Epoch : 6 | Train_loss : 1.0956188887357712 | Train_acc : 0.25 | Test_loss : 1.1463263432184856 | Test_acc : 0.2604166666666667
# torch.Size([32, 10, 32, 32])
# torch.Size([32, 10, 16, 16])
# torch.Size([32, 3])
# torch.Size([32, 10, 32, 32])
# torch.Size([32, 10, 16, 16])
# torch.Size([32, 3])
# torch.Size([32, 10, 32, 32])
# torch.Size([32, 10, 16, 16])
# torch.Size([32, 3])
# torch.Size([32, 10, 32, 32])
# torch.Size([32, 10, 16, 16])
# torch.Size([32, 3])
# torch.Size([32, 10, 32, 32])
# torch.Size([32, 10, 16, 16])
# torch.Size([32, 3])
# torch.Size([32, 10, 32, 32])
# torch.Size([32, 10, 16, 16])
# torch.Size([32, 3])
# torch.Size([32, 10, 32, 32])
# torch.Size([32, 10, 16, 16])
# torch.Size([32, 3])
# torch.Size([1, 10, 32, 32])
# torch.Size([1, 10, 16, 16])
# torch.Size([1, 3])
# torch.Size([32, 10, 32, 32])
# torch.Size([32, 10, 16, 16])
# torch.Size([32, 3])
# torch.Size([32, 10, 32, 32])
# torch.Size([32, 10, 16, 16])
# torch.Size([32, 3])
# torch.Size([11, 10, 32, 32])
# torch.Size([11, 10, 16, 16])
# torch.Size([11, 3])
# Epoch : 7 | Train_loss : 1.1187599897384644 | Train_acc : 0.3046875 | Test_loss : 1.1417603095372517 | Test_acc : 0.28125
# torch.Size([32, 10, 32, 32])
# torch.Size([32, 10, 16, 16])
# torch.Size([32, 3])
# torch.Size([32, 10, 32, 32])
# torch.Size([32, 10, 16, 16])
# torch.Size([32, 3])
# torch.Size([32, 10, 32, 32])
# torch.Size([32, 10, 16, 16])
# torch.Size([32, 3])
# torch.Size([32, 10, 32, 32])
# torch.Size([32, 10, 16, 16])
# torch.Size([32, 3])
# torch.Size([32, 10, 32, 32])
# torch.Size([32, 10, 16, 16])
# torch.Size([32, 3])
# torch.Size([32, 10, 32, 32])
# torch.Size([32, 10, 16, 16])
# torch.Size([32, 3])
# torch.Size([32, 10, 32, 32])
# torch.Size([32, 10, 16, 16])
# torch.Size([32, 3])
# torch.Size([1, 10, 32, 32])
# torch.Size([1, 10, 16, 16])
# torch.Size([1, 3])
# torch.Size([32, 10, 32, 32])
# torch.Size([32, 10, 16, 16])
# torch.Size([32, 3])
# torch.Size([32, 10, 32, 32])
# torch.Size([32, 10, 16, 16])
# torch.Size([32, 3])
# torch.Size([11, 10, 32, 32])
# torch.Size([11, 10, 16, 16])
# torch.Size([11, 3])
# Epoch : 8 | Train_loss : 1.103942334651947 | Train_acc : 0.34765625 | Test_loss : 1.1098981698354085 | Test_acc : 0.19791666666666666
# torch.Size([32, 10, 32, 32])
# torch.Size([32, 10, 16, 16])
# torch.Size([32, 3])
# torch.Size([32, 10, 32, 32])
# torch.Size([32, 10, 16, 16])
# torch.Size([32, 3])
# torch.Size([32, 10, 32, 32])
# torch.Size([32, 10, 16, 16])
# torch.Size([32, 3])
# torch.Size([32, 10, 32, 32])
# torch.Size([32, 10, 16, 16])
# torch.Size([32, 3])
# torch.Size([32, 10, 32, 32])
# torch.Size([32, 10, 16, 16])
# torch.Size([32, 3])
# torch.Size([32, 10, 32, 32])
# torch.Size([32, 10, 16, 16])
# torch.Size([32, 3])
# torch.Size([32, 10, 32, 32])
# torch.Size([32, 10, 16, 16])
# torch.Size([32, 3])
# torch.Size([1, 10, 32, 32])
# torch.Size([1, 10, 16, 16])
# torch.Size([1, 3])
# torch.Size([32, 10, 32, 32])
# torch.Size([32, 10, 16, 16])
# torch.Size([32, 3])
# torch.Size([32, 10, 32, 32])
# torch.Size([32, 10, 16, 16])
# torch.Size([32, 3])
# torch.Size([11, 10, 32, 32])
# torch.Size([11, 10, 16, 16])
# torch.Size([11, 3])
# Epoch : 9 | Train_loss : 1.09614098072052 | Train_acc : 0.44140625 | Test_loss : 1.0918257236480713 | Test_acc : 0.5416666666666666
# torch.Size([32, 10, 32, 32])
# torch.Size([32, 10, 16, 16])
# torch.Size([32, 3])
# torch.Size([32, 10, 32, 32])
# torch.Size([32, 10, 16, 16])
# torch.Size([32, 3])
# torch.Size([32, 10, 32, 32])
# torch.Size([32, 10, 16, 16])
# torch.Size([32, 3])
# torch.Size([32, 10, 32, 32])
# torch.Size([32, 10, 16, 16])
# torch.Size([32, 3])
# torch.Size([32, 10, 32, 32])
# torch.Size([32, 10, 16, 16])
# torch.Size([32, 3])
# torch.Size([32, 10, 32, 32])
# torch.Size([32, 10, 16, 16])
# torch.Size([32, 3])
# torch.Size([32, 10, 32, 32])
# torch.Size([32, 10, 16, 16])
# torch.Size([32, 3])
# torch.Size([1, 10, 32, 32])
# torch.Size([1, 10, 16, 16])
# torch.Size([1, 3])
# torch.Size([32, 10, 32, 32])
# torch.Size([32, 10, 16, 16])
# torch.Size([32, 3])
# torch.Size([32, 10, 32, 32])
# torch.Size([32, 10, 16, 16])
# torch.Size([32, 3])
# torch.Size([11, 10, 32, 32])
# torch.Size([11, 10, 16, 16])
# torch.Size([11, 3])
# Epoch : 10 | Train_loss : 1.0917253196239471 | Train_acc : 0.40234375 | Test_loss : 1.0802161296208699 | Test_acc : 0.5416666666666666

# %%
print('Training time : {} seconds'.format(round(END_TIME-START_TIME, 2)))
# Out:
# Training time : 620.81 seconds

# %%
model_results
# Out:
# {'train_loss': [1.1078356504440308,
#   1.084644876420498,
#   1.1152725219726562,
#   1.0989955812692642,
#   1.098921298980713,
#   1.096383586525917,
#   1.1183543056249619,
#   1.1010172367095947,
#   1.0883031785488129,
#   1.0668021216988564],
#  'train_acc': [0.2578125,
#   0.42578125,
#   0.29296875,
#   0.2890625,
#   0.29296875,
#   0.30859375,
#   0.31640625,
#   0.36328125,
#   0.48828125,
#   0.40234375],
#  'test_loss': [1.1362075010935466,
#   1.1621671517690022,
#   1.1694695154825847,
#   1.134177525838216,
#   1.1433651447296143,
#   1.1485037803649902,
#   1.1414344310760498,
#   1.1040594975153606,
#   1.0661935806274414,
#   1.0149725675582886],
#  'test_acc': [0.2604166666666667,
#   0.19791666666666666,
#   0.19791666666666666,
#   0.19791666666666666,
#   0.19791666666666666,
#   0.2604166666666667,
#   0.3333333333333333,
#   0.20833333333333334,
#   0.5416666666666666,
#   0.5416666666666666]}

# %%
model_results.keys()
# Out:
# dict_keys(['train_loss', 'train_acc', 'test_loss', 'test_acc'])

# %%
train_loss = model_results['train_loss']
test_loss  = model_results['test_loss']

train_acc  = model_results['train_acc']
test_acc   = model_results['test_acc']

epochs = range(len(model_results['train_loss']))

# %%
plt.figure(figsize=(10, 5), dpi=150)

plt.subplot(1, 2, 1)
plt.plot(epochs, train_loss, label='train_loss')
plt.plot(epochs, test_loss,  label='test_loss')
plt.title('Loss')
plt.xlabel('Epochs')
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(epochs, train_acc, label='train_accuracy')
plt.plot(epochs, test_acc,  label='test_accuracy')
plt.title('Accuracy')
plt.xlabel('Epochs')
plt.legend()

plt.show()

# %% [markdown]
# <br>
#
# ### -> Test data 기준 정확도가 겨우 20%? (**Under-fitting**)
#
# <br>

# %%
import pickle

with open('model_result_CNN_1.pkl', 'wb') as f:
    pickle.dump(model_results, f)
